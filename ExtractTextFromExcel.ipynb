# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import openpyxl

# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/umairsalam/Documents/python'

# %%
import pandas as pd

# %%
file = "eng_80_CARDS.xlsx"

# %%
data = pd.ExcelFile(file)

# %%
print(data.sheet_names) #this returns the all the sheets in the excel file
# Out:
# ['1', '2', '3', '4', '5', '6', '7-atb', '8-atb', '9-sgn', '10-lst', '11-fth', '12-bls', '13-slf', '14-ppl']

# %%
df = data.parse('1')

# %%
df.head(15)
# Out:
#    Unnamed: 0  Unnamed: 1      Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0         NaN         NaN             NaN         NaN         NaN         NaN
# 1         NaN         NaN             NaN         NaN         NaN         NaN
# 2         NaN         NaN  This, that...!         NaN         NaN         NaN
# 3         NaN         NaN            this         NaN         NaN         NaN
# 4         NaN         NaN            that         NaN         NaN         NaN
# 5         NaN         NaN            this         NaN         NaN         NaN
# 6         NaN         NaN            that         NaN         NaN         NaN
# 7         NaN         NaN           these         NaN         NaN         NaN
# 8         NaN         NaN           those         NaN         NaN         NaN
# 9         NaN         NaN          he who         NaN         NaN         NaN
# 10        NaN         NaN         she who         NaN         NaN         NaN
# ...

# %%
df.drop(df.columns[[0,1,3,4,5,8,9,10]], axis = 1)
# Out:
#                             Unnamed: 2              Unnamed: 6  \
# 0                                  NaN                     NaN
# 1                                  NaN                     NaN
# 2                       This, that...!                     NaN
# 3                                 this              هَذَا   mg
# 4                                 that               ذالِكَ mg
# 5                                 this             هَذِهِ   fg
# 6                                 that             تِلْكَ   fg
# 7                                these         هؤُلَاء ِ mg/fg
# 8                                those        اُولئِكَ ِ mg/fg
# 9                               he who              الَّذِي mg
# 10                             she who            الَّتِي   fg
# 11                           those who          الَّذِينَ  mg
# 12                               these      هذِهِ  (for br.pl)
# 13                               those     تِلْكَ  (for br.pl)
# ...

# %%
df_updated = df.drop(df.columns[[0,1,3,4,5,8,9,10]], axis = 1)
df_updated
# Out:
#                             Unnamed: 2              Unnamed: 6  \
# 0                                  NaN                     NaN
# 1                                  NaN                     NaN
# 2                       This, that...!                     NaN
# 3                                 this              هَذَا   mg
# 4                                 that               ذالِكَ mg
# 5                                 this             هَذِهِ   fg
# 6                                 that             تِلْكَ   fg
# 7                                these         هؤُلَاء ِ mg/fg
# 8                                those        اُولئِكَ ِ mg/fg
# 9                               he who              الَّذِي mg
# 10                             she who            الَّتِي   fg
# 11                           those who          الَّذِينَ  mg
# 12                               these      هذِهِ  (for br.pl)
# 13                               those     تِلْكَ  (for br.pl)
# ...

# %%
df_updated.columns = ["Meaning1", "Arabic1", "Meaning2", "Arabic2"]
df_updated
# Out:
#                               Meaning1                 Arabic1  \
# 0                                  NaN                     NaN
# 1                                  NaN                     NaN
# 2                       This, that...!                     NaN
# 3                                 this              هَذَا   mg
# 4                                 that               ذالِكَ mg
# 5                                 this             هَذِهِ   fg
# 6                                 that             تِلْكَ   fg
# 7                                these         هؤُلَاء ِ mg/fg
# 8                                those        اُولئِكَ ِ mg/fg
# 9                               he who              الَّذِي mg
# 10                             she who            الَّتِي   fg
# 11                           those who          الَّذِينَ  mg
# 12                               these      هذِهِ  (for br.pl)
# 13                               those     تِلْكَ  (for br.pl)
# ...

# %%
df_updated.drop(df_updated.index[[0,1,15]], inplace=True)
df_updated
# Out:
#           Meaning1                 Arabic1                Meaning2  \
# 2   This, that...!                     NaN               No, No!!!
# 3             this              هَذَا   mg       (There is) no god
# 4             that               ذالِكَ mg            except Allah
# 5             this             هَذِهِ   fg    never, certainly not
# 6             that             تِلْكَ   fg                     not
# 7            these         هؤُلَاء ِ mg/fg                     not
# 8            those        اُولئِكَ ِ mg/fg                     not
# 9           he who              الَّذِي mg                     not
# 10         she who            الَّتِي   fg             yes, indeed
# 11       those who          الَّذِينَ  mg          not, other than
# 12           these      هذِهِ  (for br.pl)      besides; less than
# 13           those     تِلْكَ  (for br.pl)  except; unless; if not
# 14       those who    الَّتِي  (for br.pl)                     yes
#
#                   Arabic2
# ...

# %%
df_updated
# Out:
#           Meaning1                 Arabic1                Meaning2  \
# 2   This, that...!                     NaN               No, No!!!
# 3             this              هَذَا   mg       (There is) no god
# 4             that               ذالِكَ mg            except Allah
# 5             this             هَذِهِ   fg    never, certainly not
# 6             that             تِلْكَ   fg                     not
# 7            these         هؤُلَاء ِ mg/fg                     not
# 8            those        اُولئِكَ ِ mg/fg                     not
# 9           he who              الَّذِي mg                     not
# 10         she who            الَّتِي   fg             yes, indeed
# 11       those who          الَّذِينَ  mg          not, other than
# 12           these      هذِهِ  (for br.pl)      besides; less than
# 13           those     تِلْكَ  (for br.pl)  except; unless; if not
# 14       those who    الَّتِي  (for br.pl)                     yes
#
#                   Arabic2
# ...

# %%
csv_output = df_updated.to_csv

# %%
df_updated.to_csv('temp.csv', encoding='utf-8', index=False)

# %%
out = df_new.to_json(orient='records', force_ascii=False)

# %%
out
# Out:
# '[{"Meaning1":"This, that...!","Arabic1":"Value","Meaning2":"No, No!!!","Arabic2":"Value"},{"Meaning1":"this","Arabic1":" هَذَا   mg","Meaning2":"(There is) no god","Arabic2":" لَا     إِلهَ "},{"Meaning1":"that","Arabic1":" ذالِكَ mg","Meaning2":"except Allah","Arabic2":" إِلَّا    الله "},{"Meaning1":"this","Arabic1":" هَذِهِ   fg","Meaning2":"never, certainly not","Arabic2":" كَلَّا"},{"Meaning1":"that","Arabic1":" تِلْكَ   fg","Meaning2":"not","Arabic2":"  لَنْ  (for future)"},{"Meaning1":"these","Arabic1":" هؤُلَاء ِ mg\\/fg","Meaning2":"not","Arabic2":"  لَمْ  (for past)"},{"Meaning1":"those","Arabic1":" اُولئِكَ ِ mg\\/fg","Meaning2":"not","Arabic2":"  مَا "},{"Meaning1":"he who","Arabic1":" الَّذِي mg","Meaning2":"not","Arabic2":" لَيْسَ (لَيْسَتْ fg)"},{"Meaning1":"she who","Arabic1":" الَّتِي   fg","Meaning2":"yes, indeed","Arabic2":" بَلَى "},{"Meaning1":"those who","Arabic1":" الَّذِينَ  mg ","Meaning2":"not, other than","Arabic2":" غَيْر  "},{"Meaning1":"these","Arabic1"
# ...

# %%
with open('temp.json', 'w') as f:
    f.write(out)
